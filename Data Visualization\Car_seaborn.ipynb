# %% [markdown]
# <a href="https://colab.research.google.com/github/andy-kool/projects/blob/main/Data%20Visualization%5CCar_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
car = pd.read_csv('Car_sales.csv')

# %%
car
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0       Mitsubishi  3000GT                          0.110
# 1            Dodge  Viper                           0.916
# 2    Mercedes-Benz  CL500                           0.954
# 3       Oldsmobile  Cutlass                         1.112
# 4          Porsche  Carrera Coupe                   1.280
# ..             ...                ...                 ...
# 152          Honda  Accord                        230.902
# 153           Ford  Taurus                        245.815
# 154         Toyota  Camry                         247.994
# 155           Ford  Explorer                      276.747
# 156           Ford  F-Series                      540.561
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0              20.940000    Passenger              25.450          3.0
# 1              58.470000    Passenger              69.725          8.0
# ...

# %%
#NaNs will lead to this error - Chart cannot be created
sns.distplot(car['Fuel efficiency'])
# Out:
# <ipython-input-4-cc9c73b7fbb1>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(car['Fuel efficiency'])
# <Axes: xlabel='Fuel efficiency', ylabel='Density'>

# %%
car.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     2
# Engine size            1
# Horsepower             0
# Wheelbase              1
# Width                  1
# Length                 1
# Curb weight            2
# Fuel capacity          1
# Fuel efficiency        3
# Latest Launch          0
# dtype: int64

# %%
sns.distplot(car['Sales in thousands'], kde=False)
# Out:
# <ipython-input-6-5745e99db102>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(car['Sales in thousands'], kde=False)
# <Axes: xlabel='Sales in thousands'>

# %%
sns.regplot(data = car, y = 'Fuel efficiency', x = 'Fuel capacity', fit_reg=False)
# Out:
# <Axes: xlabel='Fuel capacity', ylabel='Fuel efficiency'>

# %%
sns.lmplot(data = car , y = 'Fuel efficiency', x = 'Fuel capacity', fit_reg=False, hue='Vehicle type')

# %%
sns.lmplot(data = car , y = 'Fuel efficiency', x = 'Fuel capacity', fit_reg=False, col='Vehicle type')

# %%
sns.jointplot(data = car, x = 'Fuel capacity', y = 'Fuel efficiency', kind='kde' )

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
plt.style.use('fivethirtyeight')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
sns.countplot(data =car, x = 'Vehicle type')
# Out:
# <Axes: xlabel='Vehicle type', ylabel='count'>

# %%
sns.barplot(y = '4-year resale value', x = 'Vehicle type', data = car)
# Out:
# <Axes: xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
sns.stripplot(y = '4-year resale value', x = 'Vehicle type', data = car)
# Out:
# <Axes: xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
sns.pairplot(car[['Horsepower', 'Fuel efficiency', 'Fuel capacity', 'Curb weight']])

# %%
sns.heatmap(car[['Horsepower', 'Curb weight', 'Fuel capacity', 'Fuel efficiency']].corr(), annot=True)
# Out:
# <Axes: >

# %%
car[['Horsepower', 'Curb weight', 'Fuel capacity', 'Fuel efficiency']].corr()
# Out:
#                  Horsepower  Curb weight  Fuel capacity  Fuel efficiency
# Horsepower         1.000000     0.610131       0.499907        -0.611332
# Curb weight        0.610131     1.000000       0.863968        -0.818402
# Fuel capacity      0.499907     0.863968       1.000000        -0.801512
# Fuel efficiency   -0.611332    -0.818402      -0.801512         1.000000

# %%
#Box and Whiskers plot

sns.boxplot(data = car, x = 'Vehicle type', y = 'Fuel capacity')
# Out:
# <Axes: xlabel='Vehicle type', ylabel='Fuel capacity'>

# %%
sns.violinplot(data = car, x = 'Vehicle type', y = 'Fuel capacity')
# Out:
# <Axes: xlabel='Vehicle type', ylabel='Fuel capacity'>
